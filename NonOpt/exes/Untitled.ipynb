# %%
import numpy as np

# %%
problems=['ActiveFaces','ChainedCB3_1','ChainedCB3_2','ChainedCrescent_1','ChainedCrescent_2','ChainedLQ','ChainedMifflin_2','MaxQ','MxHilb','QuadPoly']

# %%
settings=['original','only_inexact']

# %%
for p in problems:
    for setting in settings:
        file_name=p+'_'+setting
        f = open('./output/'+file_name+'.out', 'r')
        data = f.readlines()
        f.close()
        for i in range(len(data)):
            print(data[i])
# Out:
# +--------------------------------------------------------------+
#
# |            NonOpt = Nonsmooth Optimization Solver            |
#
# | NonOpt is released as open source code under the MIT License |
#
# | Please visit http://coral.ise.lehigh.edu/frankecurtis/nonopt |
#
# +--------------------------------------------------------------+
#
#
#
# This is NonOpt version 0.1.0
#
#
#
# Number of variables.............. : 50
#
# Direction computation strategy... : CuttingPlane
#
# Inverse Hessian update strategy.. : BFGS
#
# Line search strategy............. : WeakWolfe
#
# Point set update strategy........ : Proximity
#
# QP solver strategy............... : ActiveSet
#
# Symmetric matrix strategy........ : Dense
#
#
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ...

# %%
f=open('./output/ActiveFaces_original.out','r')
